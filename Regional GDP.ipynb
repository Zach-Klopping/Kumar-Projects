# %%
#use 3.12.7
import pandas as pd
import plotly.express as px
import numpy as np
from scipy import stats
file1= open("Regional GDP Table.xlsx", "r")
df = pd.read_excel("Regional GDP Table.xlsx")
fig=px.line(title="GDP Comparison by Region")
fig.update_yaxes(title="Real GDP (Millions of chained 2017 dollars)")
fig.update_xaxes(title="Year") 
fig.add_scatter(x=df["GeoName"], y=df["New England"], mode="lines", name="New England")
fig.add_scatter(x=df["GeoName"], y=df["Plains"], mode="lines", name="Plains")
fig.add_scatter(x=df["GeoName"], y=df["Great Lakes"], mode="lines", name="Great Lakes")
fig.add_scatter(x=df["GeoName"], y=df["Mideast"], mode="lines", name="Mideast")
fig.add_scatter(x=df["GeoName"], y=df["Southeast"], mode="lines", name="Southeast")
fig.add_scatter(x=df["GeoName"], y=df["Southwest"], mode="lines", name="Southwest")
fig.add_scatter(x=df["GeoName"], y=df["Rocky Mountain"], mode="lines", name="Rocky Mountain")
fig.add_scatter(x=df["GeoName"], y=df["Far West"], mode="lines", name="Far West")
df
# Out:
#     GeoName  New England    Mideast  Great Lakes     Plains  Southeast  \
# 0      1997     689814.2  2438052.9    2012225.1   820782.0  2734719.5
# 1      1998     717953.5  2502639.0    2082506.9   847987.9  2866446.2
# 2      1999     750272.1  2614464.5    2163842.2   872881.4  3001079.3
# 3      2000     803964.8  2713231.6    2223891.3   910542.9  3072356.4
# 4      2001     815552.4  2771541.7    2203149.1   910419.4  3118856.9
# 5      2002     819333.7  2784056.2    2243919.0   930798.8  3195086.7
# 6      2003     837234.3  2829745.8    2296970.5   965431.8  3312051.6
# 7      2004     871834.4  2907954.7    2363124.3  1002489.7  3473548.7
# 8      2005     889361.4  2976619.3    2408650.1  1032697.3  3634909.9
# 9      2006     914340.5  3029492.0    2425979.7  1047757.6  3726096.7
# 10     2007     936059.9  3077936.8    2450466.5  1071799.7  3752274.3
# 11     2008     941279.2  3089355.4    2403346.0  1092075.7  3738925.1
# ...

# %%
fig.show()
